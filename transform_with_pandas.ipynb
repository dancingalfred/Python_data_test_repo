# %%
import pandas as pd
# Out:
# C:\Users\robba\AppData\Local\Temp\ipykernel_5164\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('8f7615b1-f6ed-41e6-871c-28129b7e9afa.csv')
df.head()
# Out:
#          date  mobil2_pm10  abyvallen_winddir  mobil_2_lat  risholmen_globrad  \
# 0  2024-02-09      4.46362            64.5699      57.7253             124.40
# 1  2024-02-09      3.57322            61.4700      57.7253             146.30
# 2  2024-02-09      4.22202            58.9800      57.7253             140.70
# 3  2024-02-09      3.25991            60.5500      57.7253             117.20
# 4  2024-02-09      2.80330            58.8200      57.7253              66.23
#
#    femman_lat  mobil_3_lat  mobil2_no2  risholmen_airpressure  lejonet_temp  \
# 0     57.7088      57.7084     18.2280                1002.85        -3.122
# 1     57.7088      57.7084     15.6499                1002.71        -2.877
# 2     57.7088      57.7084     23.1686                1002.05        -2.589
# 3     57.7088      57.7084     15.7977                1001.32        -2.221
# 4     57.7088      57.7084     13.3858                1000.81        -2.175
#
#    ...  lejonet_long  abyvallen_globrad  risholmen_winddir  mobil2_pm25  \
# 0  ...       11.9923             138.90            77.5000      3.43847
# 1  ...       11.9923             137.70            91.2000      2.59998
# 2  ...       11.9923             128.60            75.0100      2.22777
# 3  ...       11.9923             100.50            66.3199      1.84818
# 4  ...       11.9923              61.45            69.1700      1.43018
#
#           time mobil_3_long  lejonet_lat  femman_globrad    mobil1_no2  \
# 0  11:00+01:00      11.9756      57.7157          128.40       15.6094
# 1  12:00+01:00      11.9756      57.7157          128.00       14.9657
# 2  13:00+01:00      11.9756      57.7157          125.60       12.5111
# 3  14:00+01:00      11.9756      57.7157          104.80       13.1867
# 4  15:00+01:00      11.9756      57.7157           56.92       9.43535
#
#    mobil1_pm10
# 0     4.666550
# 1     0.032550
# 2     1.025420
# 3     2.624940
# 4     0.452283
#
# [5 rows x 70 columns]

# %%
cols = df.columns.tolist()
cols
# Out:
# ['date',
#  'mobil2_pm10',
#  'abyvallen_winddir',
#  'mobil_2_lat',
#  'risholmen_globrad',
#  'femman_lat',
#  'mobil_3_lat',
#  'mobil2_no2',
#  'risholmen_airpressure',
#  'lejonet_temp',
#  'risholmen_temp',
#  'lejonet_rh',
#  'risholmen_rh',
#  'mobil_1_long',
#  'abyvallen_airpressure',
#  'mobil3_pm10',
#  'haga_sodra_lat',
#  'mobil_1_lat',
#  'abyvallen_rh',
#  'abyvallen_lat',
#  'abyvallen_rain',
#  'femman_rain',
#  'lejonet_windspeed',
#  'femman_o3',
#  'mobil3_no2',
#  'haga_sodra_long',
#  'femman_winddir',
#  'hagasodra_pm25',
#  'haganorra_no2',
#  'abyvallen_temp',
#  'risholmen_long',
#  'mobil_1_pm10_fid',
#  'index',
#  'risholmen_windspeed',
#  'femman_pm25',
#  'mobil_2_long',
#  'mobil_1_pm25_fid',
#  'abyvallen_long',
#  'femman_long',
#  'femman_no2',
#  'mobil1_nox',
#  'lejonet_winddir',
#  'femman_airpressure',
#  'abyvallen_windspeed',
#  'haga_norra_lat',
#  'haga_norra_long',
#  'mobil2_nox',
#  'hagasodra_pm10',
#  'lejonet_rain',
#  'risholmen_rain',
#  'femman_nox',
#  'femman_windspeed',
#  'mobil3_nox',
#  'femman_pm10',
#  'femman_temp',
#  'haganorra_nox',
#  'lejonet_globrad',
#  'risholmen_lat',
#  'femman_rh',
#  'lejonet_airpressure',
#  'lejonet_long',
#  'abyvallen_globrad',
#  'risholmen_winddir',
#  'mobil2_pm25',
#  'time',
#  'mobil_3_long',
#  'lejonet_lat',
#  'femman_globrad',
#  'mobil1_no2',
#  'mobil1_pm10']

# %%
cols = sorted(cols)
cols
# Out:
# ['abyvallen_airpressure',
#  'abyvallen_globrad',
#  'abyvallen_lat',
#  'abyvallen_long',
#  'abyvallen_rain',
#  'abyvallen_rh',
#  'abyvallen_temp',
#  'abyvallen_winddir',
#  'abyvallen_windspeed',
#  'date',
#  'femman_airpressure',
#  'femman_globrad',
#  'femman_lat',
#  'femman_long',
#  'femman_no2',
#  'femman_nox',
#  'femman_o3',
#  'femman_pm10',
#  'femman_pm25',
#  'femman_rain',
#  'femman_rh',
#  'femman_temp',
#  'femman_winddir',
#  'femman_windspeed',
#  'haga_norra_lat',
#  'haga_norra_long',
#  'haga_sodra_lat',
#  'haga_sodra_long',
#  'haganorra_no2',
#  'haganorra_nox',
#  'hagasodra_pm10',
#  'hagasodra_pm25',
#  'index',
#  'lejonet_airpressure',
#  'lejonet_globrad',
#  'lejonet_lat',
#  'lejonet_long',
#  'lejonet_rain',
#  'lejonet_rh',
#  'lejonet_temp',
#  'lejonet_winddir',
#  'lejonet_windspeed',
#  'mobil1_no2',
#  'mobil1_nox',
#  'mobil1_pm10',
#  'mobil2_no2',
#  'mobil2_nox',
#  'mobil2_pm10',
#  'mobil2_pm25',
#  'mobil3_no2',
#  'mobil3_nox',
#  'mobil3_pm10',
#  'mobil_1_lat',
#  'mobil_1_long',
#  'mobil_1_pm10_fid',
#  'mobil_1_pm25_fid',
#  'mobil_2_lat',
#  'mobil_2_long',
#  'mobil_3_lat',
#  'mobil_3_long',
#  'risholmen_airpressure',
#  'risholmen_globrad',
#  'risholmen_lat',
#  'risholmen_long',
#  'risholmen_rain',
#  'risholmen_rh',
#  'risholmen_temp',
#  'risholmen_winddir',
#  'risholmen_windspeed',
#  'time']

# %%
#move date and time to the front
cols.insert(0, cols.pop(cols.index('date')))
cols.insert(1, cols.pop(cols.index('time')))
cols
# Out:
# ['date',
#  'time',
#  'abyvallen_airpressure',
#  'abyvallen_globrad',
#  'abyvallen_lat',
#  'abyvallen_long',
#  'abyvallen_rain',
#  'abyvallen_rh',
#  'abyvallen_temp',
#  'abyvallen_winddir',
#  'abyvallen_windspeed',
#  'femman_airpressure',
#  'femman_globrad',
#  'femman_lat',
#  'femman_long',
#  'femman_no2',
#  'femman_nox',
#  'femman_o3',
#  'femman_pm10',
#  'femman_pm25',
#  'femman_rain',
#  'femman_rh',
#  'femman_temp',
#  'femman_winddir',
#  'femman_windspeed',
#  'haga_norra_lat',
#  'haga_norra_long',
#  'haga_sodra_lat',
#  'haga_sodra_long',
#  'haganorra_no2',
#  'haganorra_nox',
#  'hagasodra_pm10',
#  'hagasodra_pm25',
#  'index',
#  'lejonet_airpressure',
#  'lejonet_globrad',
#  'lejonet_lat',
#  'lejonet_long',
#  'lejonet_rain',
#  'lejonet_rh',
#  'lejonet_temp',
#  'lejonet_winddir',
#  'lejonet_windspeed',
#  'mobil1_no2',
#  'mobil1_nox',
#  'mobil1_pm10',
#  'mobil2_no2',
#  'mobil2_nox',
#  'mobil2_pm10',
#  'mobil2_pm25',
#  'mobil3_no2',
#  'mobil3_nox',
#  'mobil3_pm10',
#  'mobil_1_lat',
#  'mobil_1_long',
#  'mobil_1_pm10_fid',
#  'mobil_1_pm25_fid',
#  'mobil_2_lat',
#  'mobil_2_long',
#  'mobil_3_lat',
#  'mobil_3_long',
#  'risholmen_airpressure',
#  'risholmen_globrad',
#  'risholmen_lat',
#  'risholmen_long',
#  'risholmen_rain',
#  'risholmen_rh',
#  'risholmen_temp',
#  'risholmen_winddir',
#  'risholmen_windspeed']

# %%
df = df[cols]

# %%
df.head()
# Out:
#          date         time  abyvallen_airpressure  abyvallen_globrad  \
# 0  2024-02-09  11:00+01:00                1002.35             138.90
# 1  2024-02-09  12:00+01:00                1001.89             137.70
# 2  2024-02-09  13:00+01:00                1001.17             128.60
# 3  2024-02-09  14:00+01:00                1000.48             100.50
# 4  2024-02-09  15:00+01:00                1000.46              61.45
#
#    abyvallen_lat  abyvallen_long  abyvallen_rain  abyvallen_rh  \
# 0        57.6447         12.0021             0.0         83.90
# 1        57.6447         12.0021             0.0         81.40
# 2        57.6447         12.0021             0.0         78.29
# 3        57.6447         12.0021             0.0         76.49
# 4        57.6447         12.0021             0.0         79.67
#
#    abyvallen_temp  abyvallen_winddir  ...  mobil_3_long  \
# 0          -3.314            64.5699  ...       11.9756
# 1          -3.221            61.4700  ...       11.9756
# 2          -2.814            58.9800  ...       11.9756
# 3          -2.434            60.5500  ...       11.9756
# 4          -2.451            58.8200  ...       11.9756
#
#    risholmen_airpressure  risholmen_globrad  risholmen_lat  risholmen_long  \
# 0                1002.85             124.40        57.6923         11.7975
# 1                1002.71             146.30        57.6923         11.7975
# 2                1002.05             140.70        57.6923         11.7975
# 3                1001.32             117.20        57.6923         11.7975
# 4                1000.81              66.23        57.6923         11.7975
#
#    risholmen_rain  risholmen_rh  risholmen_temp  risholmen_winddir  \
# 0             0.0       77.4301          -3.132            77.5000
# 1             0.0       74.8300          -3.053            91.2000
# 2             0.0       71.5900          -2.815            75.0100
# 3             0.0       68.5601          -2.569            66.3199
# 4             0.0       68.5300          -2.248            69.1700
#
#    risholmen_windspeed
# 0                6.368
# 1                6.953
# 2                5.550
# 3                6.410
# 4                6.850
#
# [5 rows x 70 columns]

# %%
# df = pd.read_csv('8f7615b1-f6ed-41e6-871c-28129b7e9afa.csv')
# df.head()
# Out:
#          date  mobil2_pm10  abyvallen_winddir  mobil_2_lat  risholmen_globrad  \
# 0  2024-02-09      4.46362            64.5699      57.7253             124.40
# 1  2024-02-09      3.57322            61.4700      57.7253             146.30
# 2  2024-02-09      4.22202            58.9800      57.7253             140.70
# 3  2024-02-09      3.25991            60.5500      57.7253             117.20
# 4  2024-02-09      2.80330            58.8200      57.7253              66.23
#
#    femman_lat  mobil_3_lat  mobil2_no2  risholmen_airpressure  lejonet_temp  \
# 0     57.7088      57.7084     18.2280                1002.85        -3.122
# 1     57.7088      57.7084     15.6499                1002.71        -2.877
# 2     57.7088      57.7084     23.1686                1002.05        -2.589
# 3     57.7088      57.7084     15.7977                1001.32        -2.221
# 4     57.7088      57.7084     13.3858                1000.81        -2.175
#
#    ...  lejonet_long  abyvallen_globrad  risholmen_winddir  mobil2_pm25  \
# 0  ...       11.9923             138.90            77.5000      3.43847
# 1  ...       11.9923             137.70            91.2000      2.59998
# 2  ...       11.9923             128.60            75.0100      2.22777
# 3  ...       11.9923             100.50            66.3199      1.84818
# 4  ...       11.9923              61.45            69.1700      1.43018
#
#           time mobil_3_long  lejonet_lat  femman_globrad    mobil1_no2  \
# 0  11:00+01:00      11.9756      57.7157          128.40       15.6094
# 1  12:00+01:00      11.9756      57.7157          128.00       14.9657
# 2  13:00+01:00      11.9756      57.7157          125.60       12.5111
# 3  14:00+01:00      11.9756      57.7157          104.80       13.1867
# 4  15:00+01:00      11.9756      57.7157           56.92       9.43535
#
#    mobil1_pm10
# 0     4.666550
# 1     0.032550
# 2     1.025420
# 3     2.624940
# 4     0.452283
#
# [5 rows x 70 columns]

# %%
#change name of the date and time columns
# df.rename(columns={'date':'Date', 'time':'Time'}, inplace=True)
# df.head()
# Out:
#          Date  mobil2_pm10  abyvallen_winddir  mobil_2_lat  risholmen_globrad  \
# 0  2024-02-09      4.46362            64.5699      57.7253             124.40
# 1  2024-02-09      3.57322            61.4700      57.7253             146.30
# 2  2024-02-09      4.22202            58.9800      57.7253             140.70
# 3  2024-02-09      3.25991            60.5500      57.7253             117.20
# 4  2024-02-09      2.80330            58.8200      57.7253              66.23
#
#    femman_lat  mobil_3_lat  mobil2_no2  risholmen_airpressure  lejonet_temp  \
# 0     57.7088      57.7084     18.2280                1002.85        -3.122
# 1     57.7088      57.7084     15.6499                1002.71        -2.877
# 2     57.7088      57.7084     23.1686                1002.05        -2.589
# 3     57.7088      57.7084     15.7977                1001.32        -2.221
# 4     57.7088      57.7084     13.3858                1000.81        -2.175
#
#    ...  lejonet_long  abyvallen_globrad  risholmen_winddir  mobil2_pm25  \
# 0  ...       11.9923             138.90            77.5000      3.43847
# 1  ...       11.9923             137.70            91.2000      2.59998
# 2  ...       11.9923             128.60            75.0100      2.22777
# 3  ...       11.9923             100.50            66.3199      1.84818
# 4  ...       11.9923              61.45            69.1700      1.43018
#
#           Time mobil_3_long  lejonet_lat  femman_globrad    mobil1_no2  \
# 0  11:00+01:00      11.9756      57.7157          128.40       15.6094
# 1  12:00+01:00      11.9756      57.7157          128.00       14.9657
# 2  13:00+01:00      11.9756      57.7157          125.60       12.5111
# 3  14:00+01:00      11.9756      57.7157          104.80       13.1867
# 4  15:00+01:00      11.9756      57.7157           56.92       9.43535
#
#    mobil1_pm10
# 0     4.666550
# 1     0.032550
# 2     1.025420
# 3     2.624940
# 4     0.452283
#
# [5 rows x 70 columns]
